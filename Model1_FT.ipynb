# %% [markdown]
# *   NAME: GOUTHAM R
# *   SCHOOL: CDS
# *   EMAIL:
# goutham.r-26@scds.saiuniversity.edu.in

# %%
import tensorflow as tf
import keras
print(tf.__version__)
from tensorflow.keras.models import load_model

from tensorflow import keras
tf.random.set_seed(42)
from sklearn.metrics import precision_score, recall_score, f1_score

import numpy as np
np.random.seed(42)

import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# 2.17.1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#importing the presaved tl model files
from numpy import load

X_train_std = load('/content/drive/MyDrive/model 1/X_train_std.npy')
X_test_std = load('/content/drive/MyDrive/model 1/X_test_std.npy')

y_train = load('/content/drive/MyDrive/model 1/y_train.npy')
y_test = load('/content/drive/MyDrive/model 1/y_test.npy')

# %%
print("X_train_std_shape: {}".format(X_train_std.shape))
print("X_test_std_shape: {}".format(X_test_std.shape))
# Out:
# X_train_std_shape: (1798, 299, 299, 3)
# X_test_std_shape: (600, 299, 299, 3)

# %%
# Loading the best saved model

modelft = keras.models.load_model('/content/drive/MyDrive/model 1/tl1.keras')

# %%
modelft.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 299, 299, 3)    │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d (Conv2D)           │ (None, 149, 149, 32)   │            864 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization       │ (None, 149, 149, 32)   │             96 │ conv2d[0][0]           │
# │ (BatchNormalization)      │                        │                │                        │
# ...

# %%
#calculating the total no of layers and 25 percent of it

total_layers = len(modelft.layers)
layers_to_freeze = int(0.25 * total_layers)
print(total_layers)
print(layers_to_freeze)
# Out:
# 784
# 196

# %%
#setting the initial 25 percent of layers as non-trainable
for layer in modelft.layers[:layers_to_freeze]:
    layer.trainable = False

# Set the remaining 75% of layers as trainable
for layer in modelft.layers[layers_to_freeze:]:
    layer.trainable = True

# %%
#recompiling the model

modelft.compile(loss='sparse_categorical_crossentropy',
                optimizer='adam',
                metrics=['accuracy'])

callbacks = [
    keras.callbacks.ModelCheckpoint("bestModelft.weights.h5",
                                    monitor='val_accuracy',
                                    save_weights_only=True,
                                    save_best_only=True)
]

history = modelft.fit(x=X_train_std, y=y_train, epochs=10,
                      validation_split=0.1, batch_size=16, callbacks=callbacks)
# Out:
# Epoch 1/10
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 233s 970ms/step - accuracy: 0.9264 - loss: 0.5218 - val_accuracy: 0.3500 - val_loss: 7.3017
# Epoch 2/10
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 20s 193ms/step - accuracy: 0.9961 - loss: 0.0134 - val_accuracy: 0.9222 - val_loss: 0.1947
# Epoch 3/10
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 20s 193ms/step - accuracy: 0.9996 - loss: 0.0017 - val_accuracy: 1.0000 - val_loss: 0.0060
# Epoch 4/10
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 17s 168ms/step - accuracy: 1.0000 - loss: 1.6394e-04 - val_accuracy: 1.0000 - val_loss: 6.4942e-05
# Epoch 5/10
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 17s 168ms/step - accuracy: 1.0000 - loss: 3.2440e-05 - val_accuracy: 1.0000 - val_loss: 1.2795e-05
# Epoch 6/10
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 17s 170ms/step - accuracy: 1.0000 - loss: 3.1357e-05 - val_accuracy: 1.0000 - val_loss: 5.9071e-06
# Epoch 7/10
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 17s 168ms/step - accuracy: 1.0000 - loss: 3.7797e-05 - val_accuracy: 0.9944 - val_loss: 0.1427
# Epoch 8/10
# ...

# %%
#plot
keys = ['accuracy', 'val_accuracy']
progress = {k:v for k,v in history.history.items() if k in keys}

import pandas as pd
pd.DataFrame(progress).plot()

plt.xlabel("epochs")
plt.ylabel("accuracy")

plt.grid(True)
plt.show()

# %%
#model evaluation
testLoss_FineTune, testAccuracy_FineTune = modelft.evaluate(x = X_test_std, y = y_test)
print("Test-loss: %f, Test-accuracy: %f" % (testLoss_FineTune, testAccuracy_FineTune))
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 25s 703ms/step - accuracy: 0.9949 - loss: 0.0191
# Test-loss: 0.013017, Test-accuracy: 0.996667

# %%
#loading best weights

modelft.load_weights("bestModelft.weights.h5")

testLoss_FT, testAccuracy_FT = modelft.evaluate(x = X_test_std, y = y_test)

print("Test-loss: %f, Test-accuracy: %f" % (testLoss_FT, testAccuracy_FT))
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 113ms/step - accuracy: 0.9942 - loss: 0.0130
# Test-loss: 0.012146, Test-accuracy: 0.995000

# %%
y_proba = modelft.predict(X_test_std)
y_predict = np.argmax(y_proba, axis=-1)
print(y_predict)
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 22s 691ms/step
# [1 2 1 2 3 3 3 1 0 1 0 1 3 4 1 2 2 3 1 4 3 4 1 4 1 2 2 3 0 2 1 1 3 1 1 4 3
#  1 0 0 4 0 4 4 2 4 2 1 4 3 4 1 0 4 2 0 4 1 2 0 1 2 4 3 0 0 3 2 4 2 0 3 2 2
#  4 3 1 2 4 0 1 2 3 1 0 0 2 1 4 3 0 0 0 1 3 3 0 3 4 1 2 4 0 0 4 1 3 1 4 2 1
#  3 1 1 2 1 2 4 2 1 2 2 4 2 3 0 4 0 2 2 2 0 4 0 2 1 3 0 0 2 3 2 0 2 2 2 1 3
#  3 0 1 1 3 3 3 0 0 2 2 3 0 1 2 0 3 3 0 3 4 1 1 2 0 3 2 4 2 4 3 2 3 4 2 3 4
#  1 4 2 4 0 1 1 1 1 1 1 1 4 4 0 0 4 1 4 0 2 0 4 2 1 4 2 3 4 1 4 3 3 3 4 0 4
#  4 0 2 0 0 3 1 3 2 1 3 1 2 2 4 1 1 4 3 4 3 0 2 0 4 3 2 3 0 2 1 3 3 2 1 4 3
#  0 0 0 0 3 2 0 2 1 0 1 4 1 2 2 3 3 4 2 0 3 1 2 4 0 1 0 1 4 4 2 1 2 4 2 1 1
#  1 1 3 2 0 0 2 2 2 0 2 3 1 0 3 3 1 0 3 0 3 3 3 0 2 1 4 2 1 0 2 1 0 3 4 2 4
#  0 3 2 0 3 0 4 1 2 3 0 1 2 3 2 4 1 0 4 0 4 4 0 4 1 1 3 4 2 2 3 3 0 1 2 3 1
#  2 1 1 0 3 2 2 1 3 1 4 2 0 0 1 3 1 3 3 1 1 2 0 0 2 4 2 0 3 2 2 3 4 4 1 4 3
#  4 3 3 0 4 2 4 4 1 1 0 2 4 3 4 1 1 2 3 2 2 3 3 2 3 3 0 1 0 0 1 4 3 2 3 3 1
# ...

# %%
#precision, recall and f1-score

pScore = precision_score(y_true= y_test, y_pred = y_predict, average = 'weighted')
print("Precision: ", pScore)

rScore = recall_score(y_true= y_test, y_pred = y_predict, average = 'weighted')
print("Recall: ", rScore)

fScore = f1_score(y_true= y_test, y_pred = y_predict, average = 'weighted')
print("F1-score: ", fScore)

print("\n\n\n")
# Out:
# Precision:  0.9951171875
# Recall:  0.995
# F1-score:  0.9950128566883454

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_true = y_test, y_pred = y_predict)
# Out:
# array([[125,   0,   0,   0,   0],
#        [  0, 125,   0,   0,   0],
#        [  0,   2, 123,   0,   0],
#        [  0,   1,   0, 124,   0],
#        [  0,   0,   0,   0, 100]])

# %%
#Confusion matrix
cm = confusion_matrix(y_true = y_test, y_pred = y_predict)

fig, ax = plt.subplots(figsize=(6, 6))
ax.matshow(cm, cmap=plt.cm.Blues, alpha=0.3)

for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        ax.text(x=j, y=i, s=cm[i, j], va='center', ha='center')

ax.title.set_text('CNN\n')
plt.xlabel('Predicted label')
plt.ylabel('True label')

plt.tight_layout()
plt.savefig("ConfusionMatrix.png", dpi=300, format='png', pad_inches=0.3)
plt.show()

numbers = [0, 1, 2, 3, 4]
plants = ['Damask Rose', 'Echeveria Flower', 'Mirabilis Jalapa', 'Rain Lily', 'Zinnia Elegans']

for number, plant in zip(numbers, plants):
    print(f"{number}: {plant}")
# Out:
# 0: Damask Rose
# 1: Echeveria Flower
# 2: Mirabilis Jalapa
# 3: Rain Lily
# 4: Zinnia Elegans

# %%
cProba = modelft.predict(X_test_std[:1])

print(cProba)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 7s 7s/step
# [[1.1710494e-10 9.9999976e-01 8.9658183e-09 2.6835454e-07 4.0412978e-08]]

# %%
# Saves the best model obtained
modelft.save('/content/drive/MyDrive/Model1/Model1ft.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
